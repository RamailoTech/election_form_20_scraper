# %%
import pandas as pd
import os
import re

# %%
def get_election_df(election_type, state = 'MH'):
    if state == 'MH' and election_type == 'AE': 
        election_df = pd.read_csv('data/Maharashtra_AE.csv')
    if state == 'MH' and election_type == 'GA':
        election_df = pd.read_csv('data/Maharashtra_GA.csv')
    return election_df

# %%
# election_type = 'AE'
election_type = 'GA'
election_df = get_election_df(election_type=election_type)

# %%
def get_parties(year,AC):
    top_3 = [1,2,3]
    # Define conditions
    condition_general = (
        (election_df['Year'] == year) &
        (election_df['Constituency_No'] == AC) &
        (~election_df['Candidate'].isin(['None of the Above', 'NOTA']))
    )

    condition_inc = (
        (election_df['Party'] == 'INC')
    )

    # Use bitwise OR to combine conditions
    filtered_election_df = election_df[
        (condition_general & election_df['Position'].isin(top_3)) |
        (condition_inc & condition_general)
    ]

    return filtered_election_df.sort_values(by='Position', ascending=True)['Party'].tolist()

# %%
def evaluate_results(state,folder_path,output_dir,year:int,election_type, constituencies_count):
    # Create a DataFrame to store the summary for each file
    constituencies_df = election_df
    summary = []
    
    for i in range(1, constituencies_count+1):
        file_path = os.path.join(folder_path, f'{i}.xlsx')
        
        # check if the certain file exists in the folder 
        if os.path.exists(file_path):
            # Read the Excel file
            df = pd.read_excel(file_path)
            if df.empty:
                    summary.append({
                        'state':state,
                        'year': year,
                        'type': election_type,
                        'constituency': i,
                        'rows_less_than_50_excel' : True,
                        'files_found' : True
                    })
                    continue  

            # Compute required information
            max_SN = df.iloc[:, 0].max()  # Assuming SN is in the first column
            count_record = df.size 
            row = df.shape[0]
            column = len(df.columns)
            null_records = df.isnull().sum().sum()  # Total number of null data in the DataFrame
            total_votes_sum = df['Total'].sum()
            constituency_no =  df['Constituency'][0]
            matched_votes = constituencies_df[constituencies_df['Constituency_No'] == constituency_no]
            year_filtered = matched_votes[matched_votes['Year'] == year]
            total_votes_sum_gt = year_filtered['Votes'].sum()
            candidates_count_gt = year_filtered['Candidate'].nunique() - 1
            parties_ordered = get_parties(year, constituency_no)
            candidates_count_excel = [col for col in df.columns if col in parties_ordered or col.startswith('col') ]
            
            # Check the number of rows in excel 
            if row < 50:
                rows_less_than_50_excel = True 
            else : 
                rows_less_than_50_excel = False
                
            # Check if the columns listed in the parties_ordered are present in the excel file
            if set(parties_ordered).issubset(df.columns):
                party_mapped_correctly = True
            else : 
                party_mapped_correctly = False

            # Append the information to the summary DataFrame
            summary.append({
                'state':state,
                'year': year,
                'type': election_type,
                'constituency': i,
                'max_SN_excel': max_SN,
                'count_records_excel': count_record,
                'row_excel': row,
                'column_excel': column,
                'null_records_excel': null_records,
                'sum(Total)_excel':total_votes_sum,
                'consituency_wise_total_votes_rayan':total_votes_sum_gt,
                'count_of_candidates_excel':len(candidates_count_excel),
                'count_of_candidates(rayan_csv)':candidates_count_gt,
                'files_found' : True,
                'rows_less_than_50_excel': rows_less_than_50_excel,
                'party_mapped_correctly' : party_mapped_correctly       
            })
        else: 
            summary.append({
                        'state':state,
                        'year': year,
                        'type': election_type,
                        'constituency': i,
                        'files_found' : False,
                        'rows_less_than_50_excel' : True,
                    })
        
    # Save the summary DataFrame to a CSV file
    summary_df = pd.DataFrame(summary)
    output_file_path = os.path.join(output_dir, f'{state}_{election_type}_{year}.xlsx')
    summary_df.to_excel(output_file_path, index=False)

# %%
# Example usage
base_dir = 'results/cleaned_election_data/MH/' 
output_base_dir = 'results/evaluation_results/MH/'

election_type = 'GA' 
# election_type = 'AE'
year = 2019
state = 'MH'
constituencies_count = 288 
if election_type == 'GA':
    excel_dir = os.path.join(base_dir, f'{year}_{election_type}')
 
if election_type == 'AE': 
    excel_dir = os.path.join(base_dir, f'{year}_{election_type}')

evaluate_results(state,excel_dir,output_base_dir,year,election_type, constituencies_count)

# %%
election_type = 'GA'
election_df = get_election_df(election_type=election_type)

election_df[(election_df['Constituency_No'] == 1) & (election_df['Year'] == 2019)].sort_values(by='Position', ascending=True)
# Out:
#        Assembly_No   State_Name  Constituency_No  Poll_No  Year    PC_Name  \
# 14622           17  Maharashtra                1        0  2019  Nandurbar
# 14628           17  Maharashtra                1        0  2019  Nandurbar
# 14634           17  Maharashtra                1        0  2019  Nandurbar
# 14640           17  Maharashtra                1        0  2019  Nandurbar
# 14646           17  Maharashtra                1        0  2019  Nandurbar
# 14652           17  Maharashtra                1        0  2019  Nandurbar
# 14658           17  Maharashtra                1        0  2019  Nandurbar
# 14664           17  Maharashtra                1        0  2019  Nandurbar
# 14670           17  Maharashtra                1        0  2019  Nandurbar
# 14676           17  Maharashtra                1        0  2019  Nandurbar
# 14682           17  Maharashtra                1        0  2019  Nandurbar
# 14688           17  Maharashtra                1        0  2019  Nandurbar
#
#        PC_No Constituency_Name Constituency_Type  CandID  ... No_Terms  \
# 14622      1         Akkalkuwa                ST       5  ...      0.0
# 14628      1         Akkalkuwa                ST       4  ...      2.0
# 14634      1         Akkalkuwa                ST       1  ...      NaN
# 14640      1         Akkalkuwa                ST       8  ...      0.0
# 14646      1         Akkalkuwa                ST      10  ...      0.0
# 14652      1         Akkalkuwa                ST       6  ...      0.0
# 14658      1         Akkalkuwa                ST       9  ...      0.0
# 14664      1         Akkalkuwa                ST       7  ...      0.0
# 14670      1         Akkalkuwa                ST      11  ...      0.0
# 14676      1         Akkalkuwa                ST       3  ...      0.0
# 14682      1         Akkalkuwa                ST       2  ...      0.0
# 14688      1         Akkalkuwa                ST      12  ...      0.0
#
#       Turncoat  Incumbent  Recontest       MyNeta_education  \
# 14622     True      False      False          Post Graduate
# 14628    False       True       True          Post Graduate
# 14634      NaN        NaN        NaN                    NaN
# 14640    False      False      False              12th Pass
# 14646    False      False      False          Post Graduate
# 14652    False      False      False  Graduate Professional
# 14658    False      False      False               8th Pass
# 14664    False      False      False              10th Pass
# 14670    False      False      False              12th Pass
# 14676    False      False      False              12th Pass
# 14682    False      False       True               Graduate
# 14688    False      False      False               Graduate
#
#                   TCPD_Prof_Main   TCPD_Prof_Main_Desc TCPD_Prof_Second  \
# 14622                Agriculture                   NaN              NaN
# 14628                Agriculture                   NaN      Social Work
# 14634                        NaN                   NaN              NaN
# 14640     Labourer or Daily Wage                   NaN              NaN
# 14646  Salaried Work or Employed  Medical Professional        Education
# 14652                Agriculture                   NaN              NaN
# 14658     Labourer or Daily Wage                   NaN              NaN
# 14664                Agriculture                   NaN              NaN
# 14670                   Business          Petrol Pumps              NaN
# 14676     Labourer or Daily Wage                   NaN              NaN
# 14682         Retired or Pension                   NaN      Agriculture
# 14688                Agriculture                   NaN              NaN
#
#                                    TCPD_Prof_Second_Desc  \
# 14622                                                NaN
# 14628                                                NaN
# 14634                                                NaN
# 14640                                                NaN
# 14646  Principal or Administrator, College Professor ...
# 14652                                                NaN
# 14658                                                NaN
# 14664                                                NaN
# 14670                                                NaN
# 14676                                                NaN
# 14682                                                NaN
# 14688                                                NaN
#
#                                    Election_Type
# 14622  Lok Sabha Election (GE) (AC Segment Wise)
# 14628  Lok Sabha Election (GE) (AC Segment Wise)
# 14634  Lok Sabha Election (GE) (AC Segment Wise)
# 14640  Lok Sabha Election (GE) (AC Segment Wise)
# 14646  Lok Sabha Election (GE) (AC Segment Wise)
# 14652  Lok Sabha Election (GE) (AC Segment Wise)
# 14658  Lok Sabha Election (GE) (AC Segment Wise)
# 14664  Lok Sabha Election (GE) (AC Segment Wise)
# 14670  Lok Sabha Election (GE) (AC Segment Wise)
# 14676  Lok Sabha Election (GE) (AC Segment Wise)
# 14682  Lok Sabha Election (GE) (AC Segment Wise)
# 14688  Lok Sabha Election (GE) (AC Segment Wise)
#
# [12 rows x 43 columns]
